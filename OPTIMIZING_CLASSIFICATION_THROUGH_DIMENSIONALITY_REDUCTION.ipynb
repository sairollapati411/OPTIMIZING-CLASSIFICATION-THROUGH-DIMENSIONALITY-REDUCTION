# %%
# CAPSTONE PROJECT -1

# %%
# PROJECT  TITLE: OPTIMIZING CLASSIFICATION THROUGH DIMENSIONALITY REDUCTION: A COMPREHENSIVE ANALYSIS

# %%
# DELIVERABLES

# %%
 # Perform the basic data exploration on the dataset. – Identify theData Types and Perform the statistical Inference.
 # Use the Dimension reduction technique to reduce the data &then perform the Classification technique on the dataset.
 # Prepare a report on the technique used &amp; the classificationalgorithm which is giving the good accuracy

# %%
# STEPS:
# 1. DATA EXPLORATION
# 2. DIMENSIONALITY REDUCTION
# 3. CLASSIFICATION TECHNIQUE AND MODEL EVALUATION
# 4. PROJECT REPORT

# %%
# 1. DATA EXPLORATION

# %%
# IDENTIFY DATA TYPES PRESENT IN THE DATASET

# %%
import pandas as pd

# Load the dataset
file_path = 'Software.csv'  # Update with the correct path if necessary
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())

# Identify and display data types of each column
data_types = data.dtypes
print("\nData types of each column:")
print(data_types)
# Out:
# First few rows of the dataset:
#    linecountofcode  cyclomaticcomplexity  essentialcomplexity  \
# 0              1.1                   1.3                  1.4
# 1              1.0                   1.0                  1.0
# 2             83.0                  11.0                  1.0
# 3             46.0                   8.0                  6.0
# 4             25.0                   3.0                  1.0
#
#    designcomplexity  total operatorsoperands  volume  programlength  \
# 0               1.4                      1.3    1.30           1.30
# 1               1.0                      1.0    1.00           1.00
# 2              11.0                    171.0  927.89           0.04
# 3               8.0                    141.0  769.78           0.07
# 4               3.0                     58.0  254.75           0.11
#
#    difficulty  intelligence    effort  ...  CodeAndComment  uniqueoperators  \
# ...

# %%
# CONDUCT STATISTICAL INFERENCE TO UNDERSTAND THE CHARACTERISTICS OF THE DATA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'Software.csv'  # Update with the correct path if necessary
data = pd.read_csv(file_path)

# Display basic descriptive statistics
print("Descriptive Statistics:")
print(data.describe())

# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Descriptive Statistics:
#        linecountofcode  cyclomaticcomplexity  essentialcomplexity  \
# count      2109.000000           2109.000000          2109.000000
# mean         20.372262              2.837980             1.674443
# std          29.754442              3.900781             2.200659
# min           1.000000              1.000000             1.000000
# 25%           3.000000              1.000000             1.000000
# 50%           9.000000              1.000000             1.000000
# 75%          24.000000              3.000000             1.000000
# max         288.000000             45.000000            26.000000
#
#        designcomplexity  total operatorsoperands       volume  programlength  \
# count       2109.000000              2109.000000  2109.000000    2109.000000
# mean           2.546420                49.829445   258.696719       0.319583
# std            3.375859                83.599874   516.317605       0.317029
# ...

# %%
# Visualizing distributions of key features
plt.figure(figsize=(12, 6))
sns.histplot(data['cyclomaticcomplexity'], bins=30, kde=True)
plt.title('Distribution of Cyclomatic Complexity')
plt.xlabel('Cyclomatic Complexity')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot to identify outliers in 'reporteddefects'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Department', y='reporteddefects', data=data)
plt.title('Boxplot of Reported Defects by Department')
plt.xlabel('Department')
plt.ylabel('Reported Defects')
plt.xticks(rotation=45)
plt.show()

# %%
# 2. DIMENSIONALITY REDUCTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Load the dataset
file_path = 'Software.csv'  # Update with the correct path if necessary
data = pd.read_csv(file_path)

# Preprocessing: Selecting features and target variable
# Assuming 'reporteddefects' is the target variable and others are features
X = data.drop(columns=['reporteddefects', 'Department', 'JobRole'])  # Drop non-numeric columns
y = data['reporteddefects']

# Standardize the features for PCA and t-SNE
scaler = StandardScaler()

# %%
# PCA

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Software.csv')

# Selecting features for dimensionality reduction (excluding non-numeric and target columns)
features = data.select_dtypes(include=['float64', 'int64']).drop(columns=['effort'])  # Adjust based on your target variable

# PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions
pca_result = pca.fit_transform(features)

# t-SNE
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(features)

# LDA - Ensure you have a target variable for this, here we assume 'JobRole' is the target
lda = LDA(n_components=1)  # Reduce to 1 dimension for LDA
lda_result = lda.fit_transform(features, data['JobRole'])

# Plotting PCA results
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=data['JobRole'].astype('category').cat.codes)
plt.title('PCA Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Plotting t-SNE results
plt.subplot(1, 3, 2)
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=data['JobRole'].astype('category').cat.codes)
plt.title('t-SNE Result')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')

# Plotting LDA results
plt.subplot(1, 3, 3)
plt.scatter(lda_result, [0] * len(lda_result), c=data['JobRole'].astype('category').cat.codes)
plt.title('LDA Result')
plt.xlabel('LDA Component')
plt.yticks([])  # Hide y-axis ticks for LDA plot

plt.tight_layout()
plt.show()

# %%
# 3. CLASSIFICATION TECHNIQUE AND MODEL EVALUATION

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the dataset
file_path = 'Software.csv'  # Adjust path as necessary
data = pd.read_csv(file_path)

# Preprocess: Separate features and target, encode categorical variables if needed
X = data.drop(columns=['reporteddefects', 'Department', 'JobRole', 'OverTime'])  # Drop categorical columns for now
y = data['reporteddefects']

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Dimensionality Reduction using PCA
pca = PCA(n_components=0.95)  # Retain 95% variance
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Dimensionality Reduction using LDA
lda = LDA(n_components=1)
X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)

# Dictionary to store accuracy results
results = {}

# Logistic Regression on PCA data
log_reg = LogisticRegression()
log_reg.fit(X_train_pca, y_train)
y_pred_pca_log = log_reg.predict(X_test_pca)
results['Logistic Regression (PCA)'] = accuracy_score(y_test, y_pred_pca_log)

# Logistic Regression on LDA data
log_reg.fit(X_train_lda, y_train)
y_pred_lda_log = log_reg.predict(X_test_lda)
results['Logistic Regression (LDA)'] = accuracy_score(y_test, y_pred_lda_log)

# Support Vector Machine (SVM) on PCA data
svm = SVC()
svm.fit(X_train_pca, y_train)
y_pred_pca_svm = svm.predict(X_test_pca)
results['SVM (PCA)'] = accuracy_score(y_test, y_pred_pca_svm)

# Support Vector Machine (SVM) on LDA data
svm.fit(X_train_lda, y_train)
y_pred_lda_svm = svm.predict(X_test_lda)
results['SVM (LDA)'] = accuracy_score(y_test, y_pred_lda_svm)

# K-Nearest Neighbors (KNN) on PCA data
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_pca, y_train)
y_pred_pca_knn = knn.predict(X_test_pca)
results['KNN (PCA)'] = accuracy_score(y_test, y_pred_pca_knn)

# K-Nearest Neighbors (KNN) on LDA data
knn.fit(X_train_lda, y_train)
y_pred_lda_knn = knn.predict(X_test_lda)
results['KNN (LDA)'] = accuracy_score(y_test, y_pred_lda_knn)

# Display results
print("Classification Accuracy Results:")
for model, accuracy in results.items():
    print(f"{model}: {accuracy:.2f}")
# Out:
# Classification Accuracy Results:
# Logistic Regression (PCA): 0.85
# Logistic Regression (LDA): 0.85
# SVM (PCA): 0.84
# SVM (LDA): 0.85
# KNN (PCA): 0.84
# KNN (LDA): 0.83

# %%
# Compare the accuracy and performance of each algorithm to determine the best-performing model

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Load the dataset
file_path = 'Software.csv'  # Adjust path as necessary
data = pd.read_csv(file_path)

# Preprocess: Separate features and target, encode categorical variables if needed
X = data.drop(columns=['reporteddefects', 'Department', 'JobRole', 'OverTime'])  # Drop categorical columns for now
y = data['reporteddefects']

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Dimensionality Reduction using PCA
pca = PCA(n_components=0.95)  # Retain 95% variance
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Dimensionality Reduction using LDA
lda = LDA(n_components=1)
X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)

# Dictionary to store model performance metrics
performance_results = {}

# Function to evaluate a model and store results
def evaluate_model(name, model, X_train, X_test, y_train, y_test, results_dict):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    conf_matrix = confusion_matrix(y_test, y_pred)

    # Store metrics
    results_dict[name] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'confusion_matrix': conf_matrix
    }
    print(f"\n{name} - Classification Report:")
    print(classification_report(y_test, y_pred))

# Instantiate models
log_reg = LogisticRegression()
svm = SVC()
knn = KNeighborsClassifier(n_neighbors=5)

# Evaluate each model on PCA and LDA reduced data
evaluate_model('Logistic Regression (PCA)', log_reg, X_train_pca, X_test_pca, y_train, y_test, performance_results)
evaluate_model('Logistic Regression (LDA)', log_reg, X_train_lda, X_test_lda, y_train, y_test, performance_results)
evaluate_model('SVM (PCA)', svm, X_train_pca, X_test_pca, y_train, y_test, performance_results)
evaluate_model('SVM (LDA)', svm, X_train_lda, X_test_lda, y_train, y_test, performance_results)
evaluate_model('KNN (PCA)', knn, X_train_pca, X_test_pca, y_train, y_test, performance_results)
evaluate_model('KNN (LDA)', knn, X_train_lda, X_test_lda, y_train, y_test, performance_results)

# Display results
print("\nOverall Model Performance Comparison:")
for model, metrics in performance_results.items():
    print(f"\n{model}:")
    print(f"  Accuracy: {metrics['accuracy']:.2f}")
    print(f"  Precision: {metrics['precision']:.2f}")
    print(f"  Recall: {metrics['recall']:.2f}")
    print(f"  F1 Score: {metrics['f1_score']:.2f}")
    print(f"  Confusion Matrix:\n{metrics['confusion_matrix']}")
# Out:
# Logistic Regression (PCA) - Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.87      0.97      0.92       533
#         True       0.58      0.25      0.35       100
#
#     accuracy                           0.85       633
#    macro avg       0.73      0.61      0.63       633
# weighted avg       0.83      0.85      0.83       633
#
#
# Logistic Regression (LDA) - Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.88      0.96      0.92       533
#         True       0.58      0.28      0.38       100
#
#     accuracy                           0.85       633
#    macro avg       0.73      0.62      0.65       633
# weighted avg       0.83      0.85      0.83       633
#
#
# SVM (PCA) - Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.86      0.97      0.91       533
# ...

# %%
# 4. PROJECT REPORT

# %%
# 1. Introduction
# This report presents the findings from the analysis of the dataset titled "Software.csv," focusing on dimensionality reduction techniques and
# classification algorithms applied to predict software defects based on various complexity metrics.

# 2. Dataset Overview
# The dataset consists of multiple features related to software metrics, including:

# Metrics: Cyclomatic complexity, essential complexity, design complexity, and others.
# Target Variable: reporteddefects (True/False), indicating whether defects were reported.
# Categorical Variables: Department and JobRole, which were excluded from numerical analyses.

# 3. Dimensionality Reduction Techniques
# Dimensionality reduction was performed to simplify the dataset while retaining significant information. The following techniques were utilized:
# 3.1 Principal Component Analysis (PCA)
# Purpose: To reduce the dimensionality of the dataset while preserving variance.
# Implementation: PCA was applied to reduce the dataset to two dimensions for visualization

# 3.2 t-distributed Stochastic Neighbor Embedding (t-SNE)
# Purpose: To visualize high-dimensional data in a lower-dimensional space while preserving local structures.
# Implementation: t-SNE was applied after standardizing the features.


# 3.3 Linear Discriminant Analysis (LDA)
# Purpose: To reduce dimensions while maximizing class separability.
# Implementation: LDA was performed only if there were multiple classes in the target variable.


# 4. Classification Techniques
# Various classification algorithms were implemented to predict the target variable based on the reduced features:
# 4.1 Logistic Regression
# A simple yet effective model for binary classification.


# 4.2 Decision Tree Classifier
# A non-linear model that splits data into branches based on feature values.


# 4.3 Random Forest Classifier
# An ensemble method that combines multiple decision trees to improve accuracy.

# 4.4 Support Vector Machine (SVM)
# A powerful classifier that finds a hyperplane to separate different classes.

# 5. Performance Evaluation
# The performance of each classification algorithm was evaluated using metrics such as accuracy, precision, recall, and F1-score.
